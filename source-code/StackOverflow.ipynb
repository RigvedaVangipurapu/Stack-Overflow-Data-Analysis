# %%
import os
import pyspark
from pyspark.sql import SparkSession
import pyspark.sql.functions 
from pyspark.sql.functions import hour, split
from pyspark.sql.types import StructType,StructField, StringType, FloatType, IntegerType
from pyspark.sql.functions import *
conf = pyspark.SparkConf()
conf.set('spark.ui.proxyBase', '/user/' + os.environ['JUPYTERHUB_USER'] + '/proxy/4041')
conf.set('spark.sql.repl.eagerEval.enabled', True)
sc = pyspark.SparkContext(conf=conf)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/conda/envs/bigdata/lib/python3.8/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/05/05 08:08:59 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark = pyspark.SQLContext.getOrCreate(sc)
sc
# Out:
# /opt/conda/envs/bigdata/lib/python3.8/site-packages/pyspark/sql/context.py:125: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# <SparkContext master=local[*] appName=pyspark-shell>

# %%
path = 'cs&se_posts_csv/'

# %%
df_a = spark.read.option("header", "false").csv('cs&se_posts_csv/part-00000')

# %%
df_b = spark.read.option("header", "false").csv('cs&se_posts_csv/*')
df_b.count()
# Out:
# 222708

# %%
# df_b

df_f = df_b.withColumnRenamed("_c0",'Id')
df_f = df_f.withColumnRenamed("_c1","PostTypeId")
df_f = df_f.withColumnRenamed("_c2","AcceptedAnswerId")
df_f = df_f.withColumnRenamed("_c3","ParentId")
df_f = df_f.withColumnRenamed("_c4","CreationDate")
df_f = df_f.withColumnRenamed("_c5","DeletionDte")
df_f = df_f.withColumnRenamed("_c6","Score")
df_f = df_f.withColumnRenamed("_c7","ViewCount")
df_f = df_f.withColumnRenamed("_c8","Body")
df_f = df_f.withColumnRenamed("_c9","OwnerUserId")
df_f = df_f.withColumnRenamed("_c10","OwnerDisplayName")
df_f = df_f.withColumnRenamed("_c11","LastEditorUserId")
df_f = df_f.withColumnRenamed("_c12","LastEditorDisplayName")
df_f = df_f.withColumnRenamed("_c13","LastEditDate")
df_f = df_f.withColumnRenamed("_c14","LastActivityDate")
df_f = df_f.withColumnRenamed("_c15","Title")
df_f = df_f.withColumnRenamed("_c16","Tags")
df_f = df_f.withColumnRenamed("_c17","AnswerCount")
df_f = df_f.withColumnRenamed("_c18","CommentCount")
df_f = df_f.withColumnRenamed("_c19","FavoriteCount")
df_f = df_f.withColumnRenamed("_c20","ClosedDate")
df_f = df_f.withColumnRenamed("_c21","CommunityOwnedDate")

# %%
df_f.printSchema()
# Out:
# root
#  |-- Id: string (nullable = true)
#  |-- PostTypeId: string (nullable = true)
#  |-- AcceptedAnswerId: string (nullable = true)
#  |-- ParentId: string (nullable = true)
#  |-- CreationDate: string (nullable = true)
#  |-- DeletionDte: string (nullable = true)
#  |-- Score: string (nullable = true)
#  |-- ViewCount: string (nullable = true)
#  |-- Body: string (nullable = true)
#  |-- OwnerUserId: string (nullable = true)
#  |-- OwnerDisplayName: string (nullable = true)
#  |-- LastEditorUserId: string (nullable = true)
#  |-- LastEditorDisplayName: string (nullable = true)
#  |-- LastEditDate: string (nullable = true)
#  |-- LastActivityDate: string (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- AnswerCount: string (nullable = true)
#  |-- CommentCount: string (nullable = true)
#  |-- FavoriteCount: string (nullable = true)
#  |-- ClosedDate: string (nullable = true)
#  |-- CommunityOwnedDate: string (nullable = true)

# %%
df_f
# Out:
# +------+----------+----------------+--------+--------------------+-----------+-----+---------+--------------------+-----------+----------------+----------------+---------------------+--------------------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+------------------+
# |    Id|PostTypeId|AcceptedAnswerId|ParentId|        CreationDate|DeletionDte|Score|ViewCount|                Body|OwnerUserId|OwnerDisplayName|LastEditorUserId|LastEditorDisplayName|        LastEditDate|    LastActivityDate|               Title|                Tags|AnswerCount|CommentCount|FavoriteCount|ClosedDate|CommunityOwnedDate|
# +------+----------+----------------+--------+--------------------+-----------+-----+---------+--------------------+-----------+----------------+----------------+---------------------+--------------------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+------------------+
# |325744|         1|          325787|    null|2016-07-25T23:13:...|       null|    2|      151|&lt;p&gt;Imagine ...|     221222|            null|           61852|                 null|2016-07-26T12:18:...|2016-07-26T12:37:...|Base Class vs Com...|&lt;design&gt;&lt...|          3|           5|         null|      null|              null|
# |325745|         2|            null|  325744|2016-07-25T23:36:...|       null|    2|     null|&lt;p&gt;Second o...|     233780|            null|            null|                 null|                null|2016-07-25T23:36:...|                null|                null|       null|           1|         null|      null|              null|
# |325746|         2|            null|  325743|2016-07-25T23:54:...|       null|    0|     null|&lt;p&gt;First of...|     131624|            null|              -1|                 null|2017-05-23T11:33:...|2016-07-26T00:07:...|                null|                null|       null|           1|         null|      null|              null|
# |325749|         1|          325756|    null|2016-07-26T00:35:...|       null|    0|      907|&lt;p&gt;I am try...|     236944|            null|              -1|                 null|2020-06-16T10:01:...|2016-07-26T12:54:...|When NOT to use a...|&lt;object-orient...|          3|           3|         null|      null|              null|
# |325750|         2|            null|  325743|2016-07-26T00:39:...|       null|    0|     null|&lt;p&gt;An objec...|     223532|            null|            null|                 null|                null|2016-07-26T00:39:...|                null|                null|       null|           0|         null|      null|              null|
# |325751|         1|          325754|    null|2016-07-26T01:11:...|       null|    1|       54|&lt;p&gt;In my ap...|     237117|            null|            null|                 null|                null|2016-07-26T01:56:...|Should different ...|&lt;design-patter...|          1|           1|         null|      null|              null|
# |325752|         2|            null|  325386|2016-07-26T01:24:...|       null|    3|     null|&lt;h2&gt;Are you...|     220117|            null|          220117|                 null|2016-09-11T21:26:...|2016-09-11T21:26:...|                null|                null|       null|           2|         null|      null|              null|
# |325753|         2|            null|  325641|2016-07-26T01:49:...|       null|    1|     null|&lt;p&gt;If you a...|     199871|            null|              -1|                 null|2017-04-12T07:31:...|2016-07-26T01:49:...|                null|                null|       null|           1|         null|      null|              null|
# |325754|         2|            null|  325751|2016-07-26T01:56:...|       null|    3|     null|&lt;p&gt;I tend t...|     204829|            null|            null|                 null|                null|2016-07-26T01:56:...|                null|                null|       null|           0|         null|      null|              null|
# |325755|         1|            null|    null|2016-07-26T02:21:...|       null|    1|      423|&lt;p&gt;Pertaini...|     116961|            null|          116961|                 null|2016-07-26T02:27:...|2016-07-26T02:27:...|Why does the last...|&lt;algorithms&gt...|          0|           0|         null|      null|              null|
# |325756|         2|            null|  325749|2016-07-26T02:23:...|       null|    2|     null|&lt;blockquote&gt...|      63202|            null|           63202|                 null|2016-07-26T04:01:...|2016-07-26T04:01:...|                null|                null|       null|           2|         null|      null|              null|
# |325757|         2|            null|  325646|2016-07-26T02:44:...|       null|    1|     null|&lt;p&gt;I've pre...|     125615|            null|          125615|                 null|2016-07-26T03:27:...|2016-07-26T03:27:...|                null|                null|       null|           0|         null|      null|              null|
# |325758|         1|          325766|    null|2016-07-26T02:46:...|       null|    1|      357|&lt;p&gt;I'm reve...|     238634|            null|            null|                 null|                null|2016-07-26T07:36:...|Why did DirectDra...|&lt;c++&gt;&lt;c&...|          1|           0|         null|      null|              null|
# |325760|         2|            null|  325749|2016-07-26T04:51:...|       null|    2|     null|&lt;p&gt;Don't us...|      81981|            null|            null|                 null|                null|2016-07-26T04:51:...|                null|                null|       null|           0|         null|      null|              null|
# |325763|         1|            null|    null|2016-07-26T06:14:...|       null|    2|      158|&lt;p&gt;I have l...|     238647|            null|            null|                 null|                null|2016-07-26T10:43:...|Preserving log of...|&lt;functional-pr...|          1|           1|            1|      null|              null|
# |325765|         2|            null|  325681|2016-07-26T07:09:...|       null|    1|     null|&lt;p&gt;If you h...|     235135|            null|              -1|                 null|2017-04-13T12:42:...|2016-07-27T07:42:...|                null|                null|       null|           3|         null|      null|              null|
# |325766|         2|            null|  325758|2016-07-26T07:36:...|       null|    4|     null|&lt;p&gt;The exis...|      41811|            null|            null|                 null|                null|2016-07-26T07:36:...|                null|                null|       null|           0|         null|      null|              null|
# |325767|         2|            null|  325681|2016-07-26T07:59:...|       null|    1|     null|&lt;p&gt;If the p...|     164670|            null|            null|                 null|                null|2016-07-26T07:59:...|                null|                null|       null|           1|         null|      null|              null|
# |325768|         2|            null|  197961|2016-07-26T08:11:...|       null|   -3|     null|&lt;p&gt;Well, it...|     224106|            null|            null|                 null|                null|2016-07-26T08:11:...|                null|                null|       null|           1|         null|      null|              null|
# |325769|         2|            null|  325749|2016-07-26T08:36:...|       null|    2|     null|&lt;p&gt;A variab...|     172693|            null|          172693|                 null|2016-07-26T12:54:...|2016-07-26T12:54:...|                null|                null|       null|           0|         null|      null|              null|
# +------+----------+----------------+--------+--------------------+-----------+-----+---------+--------------------+-----------+----------------+----------------+---------------------+--------------------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+------------------+
# only showing top 20 rows

# %%
# import os 
# dir_path = os.path.dirname(os.path.realpath('part-00000'))
# # dir_path
# p2=os.path.realpath('part-00000')
# p2

# %%
df_f.distinct().count()
# Out:
# 222708

# %%
df_f.groupBy("Id").count().where("count > 1").show()
# Out:
# [Stage 19:===========================================>              (3 + 1) / 4]
# +------+-----+
# |    Id|count|
# +------+-----+
# |129005|    2|
# |129080|    2|
# |130866|    2|
# |131450|    2|
# |132610|    2|
# |133979|    2|
# |134523|    2|
# | 38252|    2|
# | 40740|    2|
# | 40874|    2|
# | 41105|    2|
# | 41374|    2|
# | 41785|    2|
# | 42776|    2|
# | 43085|    2|
# | 44717|    2|
# | 45141|    2|
# | 45273|    2|
# | 45540|    2|
# | 47092|    2|
# +------+-----+
# only showing top 20 rows

# %%
df_f.createOrReplaceTempView("df_f")

# %%
# df a,b,c, used to check if the duplicate ids from se and cs have relevent posts
a = spark.sql("Select Body from df_f where Id like '129005'")

# %%
a.show(truncate=False)
# Out:
# [Stage 17:===================>                                      (1 + 2) / 3]
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |&lt;p&gt;Also, you state that you're considering using Python for your GUI, but I've not heard that Python's GUI tools are any better than Java's Swing library, one that I feel is quite powerful if you know it well and can be used to good effect. &lt;/p&gt;&#xA;&#xA;&lt;p&gt;If anyone has hard data that suggests I'm wrong, please post the link. I'm all about learning.&lt;/p&gt;&#xA;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |&lt;h1&gt;Impossibility result #1: dropped events&lt;/h1&gt;&#xA;&lt;p&gt;The problem cannot be solved in general; there is no way to guarantee that your requirements will be met if some events are dropped (i.e., not received).  Consider first this stream:&lt;/p&gt;&#xA;&lt;pre&gt;&lt;code&gt;e1 = { name: Jhon, timestamp: 1 }&#xA;e2 = { name: Jhon, timestamp: 4 }&#xA;&lt;/code&gt;&lt;/pre&gt;&#xA;&lt;p&gt;where the algorithm sees both events.  Next, consider this stream:&lt;/p&gt;&#xA;&lt;pre&gt;&lt;code&gt;e1' = { name: Jhon, timestamp: 1 }&#xA;e2' = { name: Pete, timestamp: 2 }&#xA;e3' = { name: Jhon, timestamp: 3 }&#xA;e4' = { name: Jhon, timestamp: 4 }&#xA;&lt;/code&gt;&lt;/pre&gt;&#xA;&lt;p&gt;where the algorithm sees only the events &lt;code&gt;e1'&lt;/code&gt;,&lt;code&gt;e4'&lt;/code&gt; (the other events are lost and never received).  You might notice that what the algorithm sees in both cases is identical, so its outputs will be identical in both cases.  However, the correct answer differs in these two cases, so there is no hope for an algorithm that always produces a correct output.  (The correct response in the first case is to produce no notifications; the correct response in the second case is to produce two notifications, one to indicate that the predicate is false after receiving &lt;code&gt;e2'&lt;/code&gt;, and one to indicate that the predicate is true after receiving &lt;code&gt;e3'&lt;/code&gt;.)&lt;/p&gt;&#xA;&lt;p&gt;It is not clear how to adapt the requirements to deal with this situation.  The only plausible solution I can see is to say that the notifications that are produced should depend only on the received events, not on the events that are sent.  This is equivalent to specifying that events cannot be dropped.&lt;/p&gt;&#xA;&lt;h1&gt;Impossibility result #2: re-ordered events&lt;/h1&gt;&#xA;&lt;p&gt;You state that you must be able to handle re-ordered events, without storing all events in memory, and with arbitrary re-ordering. However, these requirements are incompatible: that is impossible to achieve.  Consider a long sequence of events with timestamps 2,4,6,8,10,12,...  At the end of the long sequence of events, if an event with an odd timestamp arrives, the only way to be sure you can handle it correctly is to store the entire history of past events (or past states of the object).&lt;/p&gt;&#xA;&lt;p&gt;So, you're going to have to relax the requirement about re-ordering as well.  Perhaps you're willing to store all events in memory forevermore.  (If so, you have a solution.)  Perhaps you are willing to impose a bound on re-ordering, e.g., no event will be delayed by more than 10 minutes.  (If so, you only have to store history for the past 10 minutes, and everything older can be deleted.)  Perhaps something else makes more sense in your particular situation.&lt;/p&gt;&#xA;&lt;p&gt;But the one thing that is not an option is to impose all of the strong requirements stated in your question, and require an algorithm that is always correct.&lt;/p&gt;&#xA;&lt;hr /&gt;&#xA;&lt;p&gt;I'm not aware of any literature on this and I don't particularly see any reason to expect there to be any.  It's a very specific set of requirements, and it looks to me like the resulting task is either trivial or impossible to solve.  Those usually aren't the kind of problems that tend to be studied in the literature.  Perhaps you might be interested in &lt;a href=&quot;https://en.wikipedia.org/wiki/Persistent_data_structure&quot; rel=&quot;nofollow noreferrer&quot;&gt;persistent data structures&lt;/a&gt;, but that's just a fancy way of storing the entire history of events, which you said you want to do; and you don't need a fancy data structure to do that in your particular situation.&lt;/p&gt;&#xA;|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
b = spark.sql("Select Body from df_f where Id like '129080'")

# %%
b.show(truncate=False)
# Out:
# [Stage 19:===================>                                      (1 + 2) / 3]
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |&lt;p&gt;To cut a long story short, (since this question for some reason is not getting closed,) interfaces are essential for single-inheritance languages like Java and C# because that's the only way in which you can aggregate different behaviors into a single class.&lt;/p&gt;&#xA;&#xA;&lt;p&gt;In other words, when you write class A which expects to be passed a reference to some B thing to work with, it helps if you declare B to be an interface and not an abstract class, because if it is a class then you will be forcing the author of class C who wants to write C so that it works with your A to derive their class from class B, while they may have other plans for it, which may demand that C derives from some other class D, which you may have never heard of. By writing A so that it accepts an interface of type B instead of an abstract class B, the author of C is free to derive his class from D and also implement interface B for the sake of working with your class A.&lt;/p&gt;&#xA;|
# |&lt;p&gt;So the way I usually simulate these kind of trees on paper is that I make a node &lt;strong&gt;for every move&lt;/strong&gt;. So from &lt;strong&gt;starting&lt;/strong&gt;(parent) node I make one &lt;strong&gt;node&lt;/strong&gt;(child) for &lt;strong&gt;Up&lt;/strong&gt;, one node for Down and you know the rest.&lt;/p&gt;&#xA;&lt;p&gt;Once it moves to that new space &lt;strong&gt;reevaluate&lt;/strong&gt; again and make more nodes using that new space in the grid. Hope this helps!&lt;/p&gt;&#xA;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
c = spark.sql("Select Body from df_f where Id like '41785'")

# %%
c.show(truncate=False)
# Out:
# [Stage 21:======================================>                   (2 + 1) / 3]
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Body                                                                                                                                                                                                                                                            |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |&lt;p&gt;What is the intuition behind the &lt;em&gt;max-flow min-cut theorem&lt;/em&gt;? &lt;/p&gt;&#xA;&#xA;&lt;p&gt;I know that the min-cut is the dual of max-flow when formulated as a linear program, but the result seems artificial to me.&lt;/p&gt;&#xA;|
# |&lt;p&gt;If you are a dev who is moving up the food chain, then &lt;a href=&quot;http://rads.stackoverflow.com/amzn/click/1590590171&quot; rel=&quot;nofollow&quot;&gt;Herding Cats&lt;/a&gt; is a great read aimed at that situation.&lt;/p&gt;&#xA;           |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
from pyspark.sql.window import Window

from pyspark.sql.functions import monotonically_increasing_id,row_number

df =df_f.withColumn("row_idx",row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df
# Out:
# 22/05/05 08:14:02 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 08:14:02 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 08:14:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 08:14:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +------+----------+----------------+--------+--------------------+-----------+-----+---------+--------------------+-----------+----------------+----------------+---------------------+--------------------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+------------------+-------+
# |    Id|PostTypeId|AcceptedAnswerId|ParentId|        CreationDate|DeletionDte|Score|ViewCount|                Body|OwnerUserId|OwnerDisplayName|LastEditorUserId|LastEditorDisplayName|        LastEditDate|    LastActivityDate|               Title|                Tags|AnswerCount|CommentCount|FavoriteCount|ClosedDate|CommunityOwnedDate|row_idx|
# |325758|         1|          325766|    null|2016-07-26T02:46:...|       null|    1|      357|&lt;p&gt;I'm reve...|     238634|            null|            null|                 null|                null|2016-07-26T07:36:...|Why did DirectDra...|&lt;c++&gt;&lt;c&...|          1|           0|         null|      null|              null|     13|
# |325760|         2|            null|  325749|2016-07-26T04:51:...|       null|    2|     null|&lt;p&gt;Don't us...|      81981|            null|            null|                 null|                null|2016-07-26T04:51:...|                null|                null|       null|           0|         null|      null|              null|     14|
# |325763|         1|            null|    null|2016-07-26T06:14:...|       null|    2|      158|&lt;p&gt;I have l...|     238647|            null|            null|                 null|                null|2016-07-26T10:43:...|Preserving log of...|&lt;functional-pr...|          1|           1|            1|      null|              null|     15|
# |325765|         2|            null|  325681|2016-07-26T07:09:...|       null|    1|     null|&lt;p&gt;If you h...|     235135|            null|              -1|                 null|2017-04-13T12:42:...|2016-07-27T07:42:...|                null|                null|       null|           3|         null|      null|              null|     16|
# |325766|         2|            null|  325758|2016-07-26T07:36:...|       null|    4|     null|&lt;p&gt;The exis...|      41811|            null|            null|                 null|                null|2016-07-26T07:36:...|                null|                null|       null|           0|         null|      null|              null|     17|
# |325767|         2|            null|  325681|2016-07-26T07:59:...|       null|    1|     null|&lt;p&gt;If the p...|     164670|            null|            null|                 null|                null|2016-07-26T07:59:...|                null|                null|       null|           1|         null|      null|              null|     18|
# |325768|         2|            null|  197961|2016-07-26T08:11:...|       null|   -3|     null|&lt;p&gt;Well, it...|     224106|            null|            null|                 null|                null|2016-07-26T08:11:...|                null|                null|       null|           1|         null|      null|              null|     19|
# |325769|         2|            null|  325749|2016-07-26T08:36:...|       null|    2|     null|&lt;p&gt;A variab...|     172693|            null|          172693|                 null|2016-07-26T12:54:...|2016-07-26T12:54:...|                null|                null|       null|           0|         null|      null|              null|     20|
# +------+----------+----------------+--------+--------------------+-----------+-----+---------+--------------------+-----------+----------------+----------------+---------------------+--------------------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+------------------+-------+
# only showing top 20 rows

# %%
#CHECKING IF MAX OF ID = number of ROWS
row1 = df.agg({"row_idx": "max"}).collect()[0]
# Out:
# 22/05/05 08:25:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 08:25:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.

# %%
print(row1)
# Out:
# Row(max(row_idx)=222708)

# %%
df = df.drop('DeletionDte','OwnerDisplayName','LastEditorUserId','LastEditorDisplayName','LastEditDate','CommunityOwnedDate')
df
# Out:
# 22/05/05 08:25:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 08:25:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 08:25:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 08:25:48 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+-------+
# |    Id|PostTypeId|AcceptedAnswerId|ParentId|        CreationDate|Score|ViewCount|                Body|OwnerUserId|    LastActivityDate|               Title|                Tags|AnswerCount|CommentCount|FavoriteCount|ClosedDate|row_idx|
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+-------+
# only showing top 20 rows

# %% [markdown]
# ### Programming language Analysis

# %%
df.select('Body').where("Body like '%JavaScript%' or Body like '%Python%' or Body like '%Java%' or Body like '%PHP%' or Body like '%C++%'or Body like '%CSS%'or Body like'%TypeScript%'\
                 or Body like '%Ruby%'or Body like '%C%'or Body like '%Swift%'or Body like '%R%'or Body like '%Objective-C%'\
                 or Body like '%Shell%' or Body like'%Scala%'or Body like'%Go%'or Body like'%PowerShell%\
                 'or Body like'%Kotlin%'or Body like'%Rust%'or Body like'%Perl%' ").count()
# Out:
# 134778

# %%
df.count()
# Out:
# 222708

# %%
(134778/222708)*100
# Out:
# 60.51780807155558

# %% [markdown]
# ### Number of questions per day(should be able to visualise by month)

# %%
df.select("CreationDate","LastActivityDate").show(truncate=False)
# Out:
# +-----------------------+-----------------------+
# |CreationDate           |LastActivityDate       |
# +-----------------------+-----------------------+
# |2016-07-25 23:13:01.740|2016-07-26 12:37:06.900|
# |2016-07-25 23:36:01.087|2016-07-25 23:36:01.087|
# |2016-07-25 23:54:10.340|2016-07-26 00:07:44.737|
# |2016-07-26 00:35:47.573|2016-07-26 12:54:27.840|
# |2016-07-26 00:39:50.890|2016-07-26 00:39:50.890|
# |2016-07-26 01:11:21.130|2016-07-26 01:56:56.337|
# |2016-07-26 01:24:02.273|2016-09-11 21:26:49.653|
# |2016-07-26 01:49:18.553|2016-07-26 01:49:18.553|
# |2016-07-26 01:56:56.337|2016-07-26 01:56:56.337|
# |2016-07-26 02:21:50.260|2016-07-26 02:27:44.073|
# |2016-07-26 02:23:59.397|2016-07-26 04:01:43.087|
# |2016-07-26 02:44:41.590|2016-07-26 03:27:53.320|
# |2016-07-26 02:46:58.930|2016-07-26 07:36:56.637|
# |2016-07-26 04:51:20.550|2016-07-26 04:51:20.550|
# |2016-07-26 06:14:17.913|2016-07-26 10:43:34.670|
# |2016-07-26 07:09:19.733|2016-07-27 07:42:24.490|
# |2016-07-26 07:36:56.637|2016-07-26 07:36:56.637|
# |2016-07-26 07:59:57.443|2016-07-26 07:59:57.443|
# |2016-07-26 08:11:34.230|2016-07-26 08:11:34.230|
# |2016-07-26 08:36:51.763|2016-07-26 12:54:27.840|
# +-----------------------+-----------------------+
# only showing top 20 rows

# %%
# Removing extra T
df = df.withColumn('CreationDate', regexp_replace('CreationDate', 'T', ' '))
df = df.withColumn('LastActivityDate', regexp_replace('LastActivityDate', 'T', ' '))

# %%
df
# Out:
# 22/05/05 08:55:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 08:55:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# DataFrame[Id: string, PostTypeId: string, AcceptedAnswerId: string, ParentId: string, CreationDate: string, Score: string, ViewCount: string, Body: string, OwnerUserId: string, LastActivityDate: string, Title: string, Tags: string, AnswerCount: string, CommentCount: string, FavoriteCount: string, ClosedDate: string, row_idx: int]

# %%
# to create year and month columns for visualizations

from pyspark.sql.functions import year
from pyspark.sql.functions import to_date
from pyspark.sql.functions import to_timestamp,date_format
from pyspark.sql.functions import col
 
df2 = df.withColumn('CreationYear',year(df.CreationDate))
df2 = df2.withColumn('CreationMonth',month(df2.CreationDate))

#### Get day from date: day of month - NOT WORKING
 
df2.withColumn("CreationDate",to_timestamp(col("CreationDate"))).withColumn("D_O_M", date_format(col("CreationDate"), "d"))
df2
# Out:
# 22/05/05 09:46:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:46:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:46:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:46:06 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+-------+------------+-------------+
# |    Id|PostTypeId|AcceptedAnswerId|ParentId|        CreationDate|Score|ViewCount|                Body|OwnerUserId|    LastActivityDate|               Title|                Tags|AnswerCount|CommentCount|FavoriteCount|ClosedDate|row_idx|CreationYear|CreationMonth|
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+-------+------------+-------------+
# |325744|         1|          325787|    null|2016-07-25 23:13:...|    2|      151|&lt;p&gt;Imagine ...|     221222|2016-07-26 12:37:...|Base Class vs Com...|&lt;design&gt;&lt...|          3|           5|         null|      null|      1|        2016|            7|
# |325745|         2|            null|  325744|2016-07-25 23:36:...|    2|     null|&lt;p&gt;Second o...|     233780|2016-07-25 23:36:...|                null|                null|       null|           1|         null|      null|      2|        2016|            7|
# |325746|         2|            null|  325743|2016-07-25 23:54:...|    0|     null|&lt;p&gt;First of...|     131624|2016-07-26 00:07:...|                null|                null|       null|           1|         null|      null|      3|        2016|            7|
# |325749|         1|          325756|    null|2016-07-26 00:35:...|    0|      907|&lt;p&gt;I am try...|     236944|2016-07-26 12:54:...|When NOT to use a...|&lt;object-orient...|          3|           3|         null|      null|      4|        2016|            7|
# |325750|         2|            null|  325743|2016-07-26 00:39:...|    0|     null|&lt;p&gt;An objec...|     223532|2016-07-26 00:39:...|                null|                null|       null|           0|         null|      null|      5|        2016|            7|
# |325751|         1|          325754|    null|2016-07-26 01:11:...|    1|       54|&lt;p&gt;In my ap...|     237117|2016-07-26 01:56:...|Should different ...|&lt;design-patter...|          1|           1|         null|      null|      6|        2016|            7|
# |325752|         2|            null|  325386|2016-07-26 01:24:...|    3|     null|&lt;h2&gt;Are you...|     220117|2016-09-11 21:26:...|                null|                null|       null|           2|         null|      null|      7|        2016|            7|
# |325753|         2|            null|  325641|2016-07-26 01:49:...|    1|     null|&lt;p&gt;If you a...|     199871|2016-07-26 01:49:...|                null|                null|       null|           1|         null|      null|      8|        2016|            7|
# |325754|         2|            null|  325751|2016-07-26 01:56:...|    3|     null|&lt;p&gt;I tend t...|     204829|2016-07-26 01:56:...|                null|                null|       null|           0|         null|      null|      9|        2016|            7|
# |325755|         1|            null|    null|2016-07-26 02:21:...|    1|      423|&lt;p&gt;Pertaini...|     116961|2016-07-26 02:27:...|Why does the last...|&lt;algorithms&gt...|          0|           0|         null|      null|     10|        2016|            7|
# |325756|         2|            null|  325749|2016-07-26 02:23:...|    2|     null|&lt;blockquote&gt...|      63202|2016-07-26 04:01:...|                null|                null|       null|           2|         null|      null|     11|        2016|            7|
# |325757|         2|            null|  325646|2016-07-26 02:44:...|    1|     null|&lt;p&gt;I've pre...|     125615|2016-07-26 03:27:...|                null|                null|       null|           0|         null|      null|     12|        2016|            7|
# |325758|         1|          325766|    null|2016-07-26 02:46:...|    1|      357|&lt;p&gt;I'm reve...|     238634|2016-07-26 07:36:...|Why did DirectDra...|&lt;c++&gt;&lt;c&...|          1|           0|         null|      null|     13|        2016|            7|
# |325760|         2|            null|  325749|2016-07-26 04:51:...|    2|     null|&lt;p&gt;Don't us...|      81981|2016-07-26 04:51:...|                null|                null|       null|           0|         null|      null|     14|        2016|            7|
# |325763|         1|            null|    null|2016-07-26 06:14:...|    2|      158|&lt;p&gt;I have l...|     238647|2016-07-26 10:43:...|Preserving log of...|&lt;functional-pr...|          1|           1|            1|      null|     15|        2016|            7|
# |325765|         2|            null|  325681|2016-07-26 07:09:...|    1|     null|&lt;p&gt;If you h...|     235135|2016-07-27 07:42:...|                null|                null|       null|           3|         null|      null|     16|        2016|            7|
# |325766|         2|            null|  325758|2016-07-26 07:36:...|    4|     null|&lt;p&gt;The exis...|      41811|2016-07-26 07:36:...|                null|                null|       null|           0|         null|      null|     17|        2016|            7|
# |325767|         2|            null|  325681|2016-07-26 07:59:...|    1|     null|&lt;p&gt;If the p...|     164670|2016-07-26 07:59:...|                null|                null|       null|           1|         null|      null|     18|        2016|            7|
# |325768|         2|            null|  197961|2016-07-26 08:11:...|   -3|     null|&lt;p&gt;Well, it...|     224106|2016-07-26 08:11:...|                null|                null|       null|           1|         null|      null|     19|        2016|            7|
# |325769|         2|            null|  325749|2016-07-26 08:36:...|    2|     null|&lt;p&gt;A variab...|     172693|2016-07-26 12:54:...|                null|                null|       null|           0|         null|      null|     20|        2016|            7|
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+----------+-------+------------+-------------+
# only showing top 20 rows

# %%
df2.count()
# Out:
# 222708

# %%
# Filtering for Questions
df3 = df2.filter(col("PostTypeId").like("1"))
df3
# Out:
# 22/05/05 09:49:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:49:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:49:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:49:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:49:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:49:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+--------------------+-------+------------+-------------+
# |    Id|PostTypeId|AcceptedAnswerId|ParentId|        CreationDate|Score|ViewCount|                Body|OwnerUserId|    LastActivityDate|               Title|                Tags|AnswerCount|CommentCount|FavoriteCount|          ClosedDate|row_idx|CreationYear|CreationMonth|
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+--------------------+-------+------------+-------------+
# |325744|         1|          325787|    null|2016-07-25 23:13:...|    2|      151|&lt;p&gt;Imagine ...|     221222|2016-07-26 12:37:...|Base Class vs Com...|&lt;design&gt;&lt...|          3|           5|         null|                null|      1|        2016|            7|
# |325749|         1|          325756|    null|2016-07-26 00:35:...|    0|      907|&lt;p&gt;I am try...|     236944|2016-07-26 12:54:...|When NOT to use a...|&lt;object-orient...|          3|           3|         null|                null|      4|        2016|            7|
# |325751|         1|          325754|    null|2016-07-26 01:11:...|    1|       54|&lt;p&gt;In my ap...|     237117|2016-07-26 01:56:...|Should different ...|&lt;design-patter...|          1|           1|         null|                null|      6|        2016|            7|
# |325823|         1|            null|    null|2016-07-26 16:27:...|    1|       90|&lt;p&gt;In a lar...|      30668|2016-07-26 16:27:...|Updating class pr...|&lt;java&gt;&lt;p...|          0|           2|         null|                null|     52|        2016|            7|
# |325829|         1|          325832|    null|2016-07-26 17:23:...|    1|      192|&lt;p&gt;Reason: ...|     238747|2016-07-26 17:46:...|Is there a concep...|&lt;bitwise-opera...|          2|           0|            0|                null|     57|        2016|            7|
# |325833|         1|          325897|    null|2016-07-26 17:33:...|    0|      590|&lt;p&gt;I'm plan...|     197148|2016-07-28 05:59:...|Including a GPL-l...|&lt;javascript&gt...|          2|           0|            1|                null|     61|        2016|            7|
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+--------------------+-------+------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Number of Answers per day (should be able to visualise by month)

# %%
# Filtering for Answers
df4 = df2.filter(col("PostTypeId").like("2"))
df4
# Out:
# 22/05/05 09:51:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:51:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:51:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:51:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:51:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 09:51:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+-----+----+-----------+------------+-------------+----------+-------+------------+-------------+
# |    Id|PostTypeId|AcceptedAnswerId|ParentId|        CreationDate|Score|ViewCount|                Body|OwnerUserId|    LastActivityDate|Title|Tags|AnswerCount|CommentCount|FavoriteCount|ClosedDate|row_idx|CreationYear|CreationMonth|
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+-----+----+-----------+------------+-------------+----------+-------+------------+-------------+
# |325745|         2|            null|  325744|2016-07-25 23:36:...|    2|     null|&lt;p&gt;Second o...|     233780|2016-07-25 23:36:...| null|null|       null|           1|         null|      null|      2|        2016|            7|
# |325746|         2|            null|  325743|2016-07-25 23:54:...|    0|     null|&lt;p&gt;First of...|     131624|2016-07-26 00:07:...| null|null|       null|           1|         null|      null|      3|        2016|            7|
# |325750|         2|            null|  325743|2016-07-26 00:39:...|    0|     null|&lt;p&gt;An objec...|     223532|2016-07-26 00:39:...| null|null|       null|           0|         null|      null|      5|        2016|            7|
# |325752|         2|            null|  325386|2016-07-26 01:24:...|    3|     null|&lt;h2&gt;Are you...|     220117|2016-09-11 21:26:...| null|null|       null|           2|         null|      null|      7|        2016|            7|
# |325753|         2|            null|  325641|2016-07-26 01:49:...|    1|     null|&lt;p&gt;If you a...|     199871|2016-07-26 01:49:...| null|null|       null|           1|         null|      null|      8|        2016|            7|
# |325754|         2|            null|  325751|2016-07-26 01:56:...|    3|     null|&lt;p&gt;I tend t...|     204829|2016-07-26 01:56:...| null|null|       null|           0|         null|      null|      9|        2016|            7|
# |325756|         2|            null|  325749|2016-07-26 02:23:...|    2|     null|&lt;blockquote&gt...|      63202|2016-07-26 04:01:...| null|null|       null|           2|         null|      null|     11|        2016|            7|
# |325757|         2|            null|  325646|2016-07-26 02:44:...|    1|     null|&lt;p&gt;I've pre...|     125615|2016-07-26 03:27:...| null|null|       null|           0|         null|      null|     12|        2016|            7|
# |325760|         2|            null|  325749|2016-07-26 04:51:...|    2|     null|&lt;p&gt;Don't us...|      81981|2016-07-26 04:51:...| null|null|       null|           0|         null|      null|     14|        2016|            7|
# |325765|         2|            null|  325681|2016-07-26 07:09:...|    1|     null|&lt;p&gt;If you h...|     235135|2016-07-27 07:42:...| null|null|       null|           3|         null|      null|     16|        2016|            7|
# |325766|         2|            null|  325758|2016-07-26 07:36:...|    4|     null|&lt;p&gt;The exis...|      41811|2016-07-26 07:36:...| null|null|       null|           0|         null|      null|     17|        2016|            7|
# |325767|         2|            null|  325681|2016-07-26 07:59:...|    1|     null|&lt;p&gt;If the p...|     164670|2016-07-26 07:59:...| null|null|       null|           1|         null|      null|     18|        2016|            7|
# |325768|         2|            null|  197961|2016-07-26 08:11:...|   -3|     null|&lt;p&gt;Well, it...|     224106|2016-07-26 08:11:...| null|null|       null|           1|         null|      null|     19|        2016|            7|
# |325769|         2|            null|  325749|2016-07-26 08:36:...|    2|     null|&lt;p&gt;A variab...|     172693|2016-07-26 12:54:...| null|null|       null|           0|         null|      null|     20|        2016|            7|
# |325773|         2|            null|  325772|2016-07-26 09:21:...|    7|     null|&lt;p&gt;The poin...|      40065|2016-07-26 09:36:...| null|null|       null|           1|         null|      null|     23|        2016|            7|
# |325774|         2|            null|  325763|2016-07-26 09:41:...|    2|     null|&lt;p&gt;I sketch...|      29020|2016-07-26 10:43:...| null|null|       null|           3|         null|      null|     24|        2016|            7|
# |325779|         2|            null|  294684|2016-07-26 10:04:...|    2|     null|&lt;p&gt;For the ...|      37450|2016-07-26 10:04:...| null|null|       null|           0|         null|      null|     25|        2016|            7|
# |325785|         2|            null|  325783|2016-07-26 11:16:...|    5|     null|&lt;p&gt;It proba...|      73048|2016-07-26 11:16:...| null|null|       null|           5|         null|      null|     28|        2016|            7|
# |325787|         2|            null|  325744|2016-07-26 12:16:...|    2|     null|&lt;p&gt;Let's ca...|      61852|2016-07-26 12:37:...| null|null|       null|           0|         null|      null|     29|        2016|            7|
# |325788|         2|            null|  325744|2016-07-26 12:35:...|    1|     null|&lt;p&gt;There re...|     235135|2016-07-26 12:35:...| null|null|       null|           1|         null|      null|     30|        2016|            7|
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+-----+----+-----------+------------+-------------+----------+-------+------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### For Accepted Answers

# %%
df_temp1 = df2.filter(col("AcceptedAnswerId").isNull())
df_temp1
df_temp1.select("AnswerCount").distinct().show()
## ANSWER COUNT MAY NOT BE 0 FOR RECORDS WITH No Accepted answers(i.e.null)
# Out:
# [Stage 157:============================>                            (2 + 2) / 4]
# +-----------+
# |AnswerCount|
# +-----------+
# |          7|
# |         15|
# |         11|
# |          3|
# |          8|
# |         28|
# |         22|
# |         16|
# |          0|
# |       null|
# |          5|
# |         18|
# |         17|
# |         26|
# |          6|
# |         19|
# |          9|
# |          1|
# |         20|
# |         10|
# +-----------+
# only showing top 20 rows

# %%
df5 = df2.filter(col("AcceptedAnswerId").isNotNull())
df5
# Out:
# 22/05/05 10:11:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 10:11:57 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 10:12:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 10:12:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 10:12:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/05/05 10:12:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------+--------------------+--------------------+-----------+------------+-------------+--------------------+-------+------------+-------------+
# |    Id|PostTypeId|AcceptedAnswerId|ParentId|        CreationDate|Score|ViewCount|                Body|OwnerUserId|    LastActivityDate|               Title|                Tags|AnswerCount|CommentCount|FavoriteCount|          ClosedDate|row_idx|CreationYear|CreationMonth|
# +------+----------+----------------+--------+--------------------+-----+---------+--------------------+-----------+--------------------